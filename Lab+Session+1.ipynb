# %%
import pandas

# %%
df = pandas.read_excel("Information is Beautiful_ Data Breaches (public).xlsx")

# %%
df
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
df1=df.fillna({
    'Entity': 'NULL',
    'alternative name':'-',
    'story':'None',
    'ORGANISATION':'default',
    'DATA SENSITIVITY':0,
    '1st source link':'https://www.scu.edu/',
    '2nd source link':'https://www.scu.edu/',
    '3rd source':'https://www.scu.edu/',
    'source name':'SCU',
    'interesting story':'n',
    'METHOD OF LEAK':'General'
    })
df1
# Out:
#                                              Entity  \
# 0                                              NULL
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
df2=df1.rename(columns={'alternative name':'Alternative_Name',
                        'story':'Story',
                        'YEAR':'Year',
                        'records lost':'Records_Lost',
                        'ORGANISATION':'Organisation',
                        'METHOD OF LEAK':'Method_Of_Leak',
                        'interesting story':'Interesting_Story',
                        'NO OF RECORDS STOLEN':'No_Of_Records',
                        'DATA SENSITIVITY':'Data_Sensitivity',
                        })
df2
# Out:
#                                              Entity  \
# 0                                              NULL
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
df2.to_excel('C:/Users/Sanjana Thakur/Desktop/MSIS/Dashboards/final.xlsx')
df2
# Out:
#                                              Entity  \
# 0                                              NULL
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...
